# %%
# -*- coding: utf-8 -*-
"""LPP Using Big M.ipynb
Automatically generated by Colaboratory.
Original file is located at
https://colab.research.google.com/drive/1TZJp49-COubXVng_6XbFLwjEGqxhAKPY
"""
from scipy.optimize import linprog
obj=[4,1]
lhs_ineq=[[-3,-4],[-1,-5]]
rhs_ineq=[-20,-15]
bnd=[(0,float("inf")),(0,float("inf"))]
opt=linprog(c=obj,A_ub=lhs_ineq, b_ub=rhs_ineq,bounds=bnd,method="interior-point")
opt
# Out:
#      con: array([], dtype=float64)
#      fun: 5.000000000236448
#  message: 'Optimization terminated successfully.'
#      nit: 5
#    slack: array([1.64281033e-10, 1.00000000e+01])
#   status: 0
#  success: True
#        x: array([6.01160437e-11, 5.00000000e+00])
